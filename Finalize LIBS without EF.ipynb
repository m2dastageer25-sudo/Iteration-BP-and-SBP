# %%
# ============================================================
# SAHA-BOLTZMANN ITERATION
# RELATIVE-ERROR UNCERTAINTY METHOD — LINEAR / WORST-CASE
#
# 10 Ca I lines + 6 Ca II lines = 16 lines
#
# Initial temperature:
#     Obtained automatically from the 10 Ca I Boltzmann plot
#
# Saha correction:
#
# Y = ln(I lambda / h c A_k g_k)
#     - z ln[ 2(2*pi*me*kB*T)^(3/2) / (h^3 Ne) ]
#
# Electron density:
#
# Ne = Delta_lambda / (2 omega) * N_reference
#
# Stark width:
#
# Delta_lambda = 0.170 +/- 0.016 nm
#
# UNCERTAINTY METHOD:
#
# Slope:
#     sigma_m from linear regression
#
# Temperature:
#     sigma_T / T = sigma_m / |m|
#
# Electron density (WORST-CASE / MAXIMUM RELATIVE-ERROR METHOD):
#     Delta_lambda and omega are independent quantities, so their
#     relative uncertainties are ADDED (not combined in quadrature).
#
#     sigma_omega (ROUTE A - worst case, no cancellation):
#     omega(T) = a + bT - cT^2 is a SUM of terms with different
#     powers of T. Each T-dependent term's own uncertainty
#     contribution is taken separately (as if independent) and
#     the magnitudes are ADDED - the two terms are NOT allowed
#     to partially cancel, even though they share the same T:
#
#     sigma_omega = ( |b| + |2cT| ) * sigma_T
#
#     (Route B, which combines b and 2cT algebraically BEFORE
#     taking the absolute value - i.e. sigma_omega = |b-2cT|*sigma_T -
#     is the more rigorous/correlated treatment, but Route A is
#     used here for consistency with the worst-case convention
#     applied everywhere else in this notebook.)
#
#     sigma_Ne/Ne = sigma_lambda/lambda + sigma_omega/omega
#
# No previous files are used.
# ============================================================


import numpy as np
import matplotlib.pyplot as plt


# ============================================================
# 1. Ca I DATA
# ============================================================


# x-axis Ek (cm-1) upper energy level
E_CaI = np.array([
    42170,
    42171,
    39335,
    38259,
    38192,
    31539,
    31539,
    31539,
    36574,
    37751
], dtype=float)

# y-axis using  "ln(λI/Akgkhc)"
Y_CaI = np.array([ 
    32.88,
    32.65,
    35.07,
    34.80,
    34.85,
    35.97,
    35.23,
    34.88,
    34.82,
    34.48
], dtype=float)


# ============================================================
# 2. Ca II DATA
# ============================================================
# x-axis Ek (cm-1) upper energy level
E_CaII = np.array([
    106139,
    106158,
    101466,
    101466,
    74714,
    74491
], dtype=float)

# y-axis Raw mean without saha correction using "ln(λI/Akgkhc)"
Y_CaII_raw = np.array([
    32.09,
    31.49,
    34.14,
    33.52,
    33.02,
    33.77
], dtype=float)


# ============================================================
# 2b. LINE-BY-LINE UNCERTAINTY INPUTS
# ============================================================
# Instrumental wavelength uncertainty: 0.05 nm for every line.
# Relative wavelength uncertainty is therefore 0.05/lambda.
# Transition-probability uncertainty follows the user's grade
# convention: C = 25%, D = 50%.
# Intensity uncertainty values are the previously established
# relative uncertainties for each line.

# Ca I: 10 lines
wavelength_CaI_nm = np.array([
    458.14, 458.58, 526.17, 558.19, 560.28,
    610.27, 612.22, 616.21, 616.95, 445.58
], dtype=float)

deltaI_over_I_CaI = np.array([
    0.00488718,
    0.005961941,
    0.001515351,
    0.003289719,
    0.003197377,
    0.001359202,
    2.52534E-05,
    0.001151712,
    0.000663147,
    0.000101008
], dtype=float)

# Ca I transition grades: C, C, D, D, D, C, C, C, D, C
grade_CaI = np.array(['C','C','D','D','D','C','C','C','D','C'])
deltaA_over_A_CaI = np.where(grade_CaI == 'D', 0.50, 0.25)

# Ca II: 6 lines -- all are C grade in the revised table.
wavelength_CaII_nm = np.array([
    315.89, 317.93, 370.60, 373.69, 393.36, 396.85
], dtype=float)

deltaI_over_I_CaII = np.array([
    0.000304534,
    0.000304534,
    0.000804556,
    0.000804556,
    0.000804556,
    0.000804556
], dtype=float)

grade_CaII = np.array(['C','C','C','C','C','C'])
deltaA_over_A_CaII = np.where(grade_CaII == 'D', 0.50, 0.25)

# Fixed instrumental wavelength uncertainty
delta_lambda_instrument = 0.05  # nm

# Relative wavelength uncertainties, line by line
deltaLambda_over_lambda_CaI = (
    delta_lambda_instrument / wavelength_CaI_nm
)
deltaLambda_over_lambda_CaII = (
    delta_lambda_instrument / wavelength_CaII_nm
)


# ============================================================
# 2c. LINEAR RELATIVE-UNCERTAINTY PROPAGATION
# ============================================================
# Boltzmann Ca I y-error:
#   Delta y = Delta I/I + Delta lambda/lambda + Delta A/A
#
# Saha-Boltzmann Ca II y-error:
#   Delta y = Delta I/I + Delta lambda/lambda + Delta A/A
#              + Delta S/S
#
# where, for the Saha factor S,
#   Delta S/S = (3/2)(Delta T/T) + Delta Ne/Ne
#
# All independent relative contributions are ADDED linearly,
# NOT combined in quadrature and NOT estimated by half-difference.
# ============================================================

def line_y_uncertainty(deltaI_over_I, deltaLambda_over_lambda, deltaA_over_A):
    return (
        deltaI_over_I
        + deltaLambda_over_lambda
        + deltaA_over_A
    )


sigma_Y_CaI_propagated = line_y_uncertainty(
    deltaI_over_I_CaI,
    deltaLambda_over_lambda_CaI,
    deltaA_over_A_CaI
)




# ============================================================
# 3. PHYSICAL CONSTANTS
# ============================================================

h = 6.62607015e-34       # J s
kB = 1.380649e-23        # J/K
me = 9.1093837e-31       # kg

# hc/kB when E is in cm^-1
hc_over_k = 1.4387769    # cm K


# ============================================================
# 4. STARK WIDTH
# ============================================================

delta_lambda = 0.25
sigma_delta_lambda = 0.0086

# nm

# Reference electron density
N_reference = 1.0e16     # cm^-3


# ============================================================
# 5. OMEGA(T)
# ============================================================

def omega_function(T):

    omega = (
        4.8767e-4
        + 1.6385e-8 * T
        - 1.8473e-13 * T**2
    )

    return omega


# ============================================================
# 6. ELECTRON DENSITY
# ============================================================

def calculate_Ne(T):

    omega = omega_function(T)

    Ne = (
        delta_lambda
        /
        (2.0 * omega)
        *
        N_reference
    )

    return omega, Ne


# ============================================================
# 7. SAHA CORRECTION
#
# Your equation:
#
# Y_coordinate =
#
# ln(I lambda / h c A_k g_k)
#
# -
#
# z ln[
#     2(2*pi*me*kB*T)^(3/2)
#     -----------------------
#             h^3 Ne
# ]
#
# For Ca II:
#
# z = 1
# ============================================================

def calculate_saha_factor(T, Ne):

    # Ne is supplied in cm^-3; convert to m^-3 for SI constants.
    Ne_m3 = Ne * 1.0e6

    S = (
        2.0
        * (2.0 * np.pi * me * kB * T)**1.5
        / (h**3 * Ne_m3)
    )

    return S


def calculate_saha_correction(T, Ne, z=1):
    # The Saha-Boltzmann coordinate contains -z*ln(S).
    S = calculate_saha_factor(T, Ne)
    return z * np.log(S)


# ============================================================
# 7b. SAHA FACTOR UNCERTAINTY
# ============================================================
# S = 2(2*pi*m_e*k*T)^(3/2)/(Ne*h^3)
# Therefore, using the requested LINEAR relative-error method:
#
# Delta S/S = (3/2)(Delta T/T) + Delta Ne/Ne
#
# Because ln(S) appears in the y-coordinate,
# Delta[ln(S)] = Delta S/S.
# For Ca II, z = 1, so the Saha contribution to Delta y is
# numerically equal to Delta S/S.
# ============================================================

def calculate_saha_uncertainty(T, sigma_T, Ne, sigma_Ne, z=1):

    relative_S_error = (
        1.5 * sigma_T / T
        + sigma_Ne / Ne
    )

    return z * relative_S_error


# ============================================================
# 8. LINEAR FIT
#
# Y = mE + b
#
# Also calculate slope uncertainty.
# ============================================================

def linear_fit(E, Y):

    N = len(E)

    # Linear regression
    m, b = np.polyfit(E, Y, 1)

    # Fitted Y values
    Y_fit = m * E + b

    # Residuals
    residuals = Y - Y_fit

    # Residual sum of squares
    SS_res = np.sum(residuals**2)

    # Degrees of freedom
    dof = N - 2

    # Residual variance
    s2 = SS_res / dof

    # Spread in E
    Sxx = np.sum((E - np.mean(E))**2)

    # Standard uncertainty of slope
    sigma_m = np.sqrt(s2 / Sxx)

    # Intercept uncertainty
    sigma_b = np.sqrt(
        s2 *
        (
            1.0 / N
            +
            np.mean(E)**2 / Sxx
        )
    )

    # R squared
    SS_tot = np.sum(
        (Y - np.mean(Y))**2
    )

    R2 = 1.0 - SS_res / SS_tot

    return (
        m,
        b,
        sigma_m,
        sigma_b,
        Y_fit,
        R2
    )


# ============================================================
# 8b. FIT-LINE UNCERTAINTY BAND (WORST CASE)
#
# Worst-case upper/lower bounds of the regression line,
# obtained by shifting slope and intercept by their maximum
# (+/- 1 sigma) uncertainties simultaneously in the direction
# that maximises the spread:
#
# Y_upper(E) = (m + sigma_m) E + (b + sigma_b)
# Y_lower(E) = (m - sigma_m) E + (b - sigma_b)
# ============================================================

def fit_uncertainty_band(E_range, m, sigma_m, b, sigma_b):

    Y_upper = (m + sigma_m) * E_range + (b + sigma_b)
    Y_lower = (m - sigma_m) * E_range + (b - sigma_b)

    return Y_lower, Y_upper


# ============================================================
# 9. TEMPERATURE FROM SLOPE
#
# m = -1.4387769 / T
#
# Therefore:
#
# T = -1.4387769 / m
# ============================================================

def temperature_from_slope(m):

    T = -hc_over_k / m

    return T


# ============================================================
# 10. TEMPERATURE UNCERTAINTY
#
# RELATIVE ERROR METHOD
#
# sigma_T / T = sigma_m / |m|
#
# Therefore:
#
# sigma_T = T * sigma_m / |m|
# ============================================================

def temperature_uncertainty(T, m, sigma_m):

    relative_error_T = (
        sigma_m / abs(m)
    )

    sigma_T = (
        T * relative_error_T
    )

    return sigma_T


# ============================================================
# 11. ELECTRON DENSITY UNCERTAINTY
#
# WORST-CASE (MAXIMUM) RELATIVE-ERROR METHOD
#
# Ne = Delta_lambda / (2 omega) * N_reference
#
# Delta_lambda (Stark width) and omega (Stark broadening
# parameter) are two INDEPENDENT measured/tabulated quantities.
# Because their individual errors could in principle combine in
# the worst possible (reinforcing) direction, the relative
# uncertainties are ADDED directly (not combined in quadrature):
#
# sigma_Ne/Ne = sigma_lambda/lambda + sigma_omega/omega
#
# Note: omega(T) = a + bT - cT^2 is a SUM of terms with
# different powers of the SAME variable, T. Per the worst-case
# convention used throughout this notebook, the linear (bT) and
# quadratic (-cT^2) terms' contributions to sigma_omega are
# taken separately and ADDED (magnitudes, no cancellation):
#
# sigma_omega = ( |b| + |2cT| ) * sigma_T   (see Section 6 below)
# ============================================================

def electron_density_uncertainty(
    T,
    sigma_T,
    omega,
    Ne
):

    # --------------------------------------------------------
    # Relative uncertainty from Stark width
    # --------------------------------------------------------

    relative_lambda_error = (
        sigma_delta_lambda
        /
        delta_lambda
    )


    # --------------------------------------------------------
    # Uncertainty in omega -- ROUTE A (worst case, no cancellation)
    #
    # omega(T) = a + bT - cT^2
    #
    # The linear term (bT) and the quadratic term (-cT^2) are
    # each treated as separate, independent contributors to the
    # uncertainty in omega. Their magnitudes are ADDED directly
    # (worst case) -- they are NOT combined algebraically first
    # (that would be Route B, which allows partial cancellation
    # since both terms share the same underlying T).
    #
    # sigma_omega = ( |b| + |2cT| ) * sigma_T
    # --------------------------------------------------------

    b_coeff = 1.6385e-8
    c_coeff = 1.8473e-13

    sigma_omega = (
        abs(b_coeff)
        +
        abs(2.0 * c_coeff * T)
    ) * sigma_T


    # --------------------------------------------------------
    # Relative omega uncertainty
    # --------------------------------------------------------

    relative_omega_error = (
        sigma_omega
        /
        abs(omega)
    )


    # --------------------------------------------------------
    # Total relative uncertainty in Ne
    #
    # WORST-CASE (MAXIMUM) RELATIVE-ERROR METHOD:
    # relative errors of independent quantities (lambda, omega)
    # are ADDED, not combined in quadrature, since we assume the
    # worst-case scenario in which both errors reinforce each
    # other (no cancellation assumed).
    # --------------------------------------------------------

    relative_Ne_error = (
        relative_lambda_error
        +
        relative_omega_error
    )


    # --------------------------------------------------------
    # Absolute uncertainty in Ne
    # --------------------------------------------------------

    sigma_Ne = (
        Ne
        *
        relative_Ne_error
    )


    return (
        sigma_Ne,
        sigma_omega,
        relative_lambda_error,
        relative_omega_error,
        relative_Ne_error
    )


# ============================================================
# 12. INITIAL Ca I BOLTZMANN PLOT
# ============================================================

(
    m_initial,
    b_initial,
    sigma_m_initial,
    sigma_b_initial,
    Yfit_initial,
    R2_initial
) = linear_fit(
    E_CaI,
    Y_CaI
)


# Initial temperature
T_initial = temperature_from_slope(
    m_initial
)


# Initial temperature uncertainty
sigma_T_initial = temperature_uncertainty(
    T_initial,
    m_initial,
    sigma_m_initial
)

# ------------------------------------------------------------
# Propagated Ca I y-error bars
#
# Delta y_CaI = Delta I/I + Delta lambda/lambda + Delta A/A
# using the requested linear relative-error method.
# ------------------------------------------------------------
sigma_Y_CaI = sigma_Y_CaI_propagated.copy()


# ============================================================
# 13. PRINT INITIAL RESULT
# ============================================================

print()
print("=" * 90)
print("INITIAL Ca I BOLTZMANN PLOT")
print("=" * 90)

print(
    f"Slope = {m_initial:.9e} +/- "
    f"{sigma_m_initial:.9e} cm"
)

print(
    f"Relative slope uncertainty = "
    f"{sigma_m_initial/abs(m_initial)*100:.3f} %"
)

print(
    f"Temperature = {T_initial:.3f} +/- "
    f"{sigma_T_initial:.3f} K"
)

print(
    f"Relative temperature uncertainty = "
    f"{sigma_T_initial/T_initial*100:.3f} %"
)

print(
    f"R^2 = {R2_initial:.6f}"
)

print("=" * 90)


# ============================================================
# 14. PLOT INITIAL Ca I
# ============================================================

plt.figure(figsize=(9, 6))

# Ca I points with empirical residual-scatter y-error bars.
# These bars represent the 1-sigma residual scatter of the
# initial 10-line regression; they are not individual intensity
# measurement uncertainties.
plt.errorbar(
    E_CaI,
    Y_CaI,
    yerr=sigma_Y_CaI,
    fmt="o",
    markersize=7,
    capsize=4,
    elinewidth=1.2,
    ecolor="black",
    label=r"Ca I lines ($\pm1\sigma_Y$, residual scatter)",
    zorder=3
)

E_line = np.linspace(
    E_CaI.min() - 500,
    E_CaI.max() + 500,
    500
)

Y_line = (
    m_initial * E_line
    +
    b_initial
)

# Worst-case fit-line uncertainty band
Y_line_lower, Y_line_upper = fit_uncertainty_band(
    E_line,
    m_initial,
    sigma_m_initial,
    b_initial,
    sigma_b_initial
)

plt.fill_between(
    E_line,
    Y_line_lower,
    Y_line_upper,
    alpha=0.2,
    label="Fit uncertainty (worst case)",
    zorder=1
)

plt.plot(
    E_line,
    Y_line,
    linewidth=2,
    label="Linear fit",
    zorder=2
)

plt.xlabel(
    r"Upper-level energy $E_k$ (cm$^{-1}$)",
    fontsize=12
)

plt.ylabel(
    "Y-coordinate",
    fontsize=12
)

plt.title(
    "Initial Boltzmann Plot — 10 Ca I Lines",
    fontsize=14
)

text_initial = (
    f"T = {T_initial:.2f} ± "
    f"{sigma_T_initial:.2f} K\n"
    f"Slope = {m_initial:.3e} ± "
    f"{sigma_m_initial:.2e} cm\n"
    f"R² = {R2_initial:.5f}"
)

plt.text(
    0.97,
    0.05,
    text_initial,
    transform=plt.gca().transAxes,
    ha="right",
    va="bottom",
    bbox=dict(
        facecolor="white",
        edgecolor="black",
        alpha=0.9
    )
)

plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()


# ============================================================
# 15. START ITERATION
#
# IMPORTANT:
# Initial temperature comes from Ca I plot.
# We do NOT use 6851 K manually.
# ============================================================

T = T_initial
sigma_T = sigma_T_initial


# Maximum number of iterations
maximum_iterations = 11

# Convergence criterion
tolerance = 0.01


# Store results
results = []


# ============================================================
# 16. SAHA-BOLTZMANN ITERATIONS
# ============================================================

for iteration in range(maximum_iterations):


    # --------------------------------------------------------
    # A. Calculate omega and electron density
    # --------------------------------------------------------

    omega, Ne = calculate_Ne(T)


    # --------------------------------------------------------
    # B. Calculate electron-density uncertainty
    # --------------------------------------------------------

    (
        sigma_Ne,
        sigma_omega,
        relative_lambda_error,
        relative_omega_error,
        relative_Ne_error
    ) = electron_density_uncertainty(
        T,
        sigma_T,
        omega,
        Ne
    )


    # --------------------------------------------------------
    # C. Calculate Saha correction
    # --------------------------------------------------------

    saha = calculate_saha_correction(
        T,
        Ne,
        z=1
    )


    # --------------------------------------------------------
    # C2. Saha-factor relative uncertainty
    # --------------------------------------------------------

    relative_S_error = calculate_saha_uncertainty(
        T,
        sigma_T,
        Ne,
        sigma_Ne,
        z=1
    )

    sigma_saha = relative_S_error  # absolute uncertainty in ln(S)

    # --------------------------------------------------------
    # D. Correct Ca II Y values and calculate line-by-line
    # y-error bars.
    #
    # Delta y_CaII = Delta I/I + Delta lambda/lambda + Delta A/A
    #                + Delta S/S
    # --------------------------------------------------------

    Y_CaII_corrected = (
        Y_CaII_raw
        -
        saha
    )

    sigma_Y_CaII_line = line_y_uncertainty(
        deltaI_over_I_CaII,
        deltaLambda_over_lambda_CaII,
        deltaA_over_A_CaII
    )

    sigma_Y_CaII_corrected = (
        sigma_Y_CaII_line
        + relative_S_error
    )


    # --------------------------------------------------------
    # E. Combine all 16 lines
    # --------------------------------------------------------

    E_all = np.concatenate([
        E_CaI,
        E_CaII
    ])

    Y_all = np.concatenate([
        Y_CaI,
        Y_CaII_corrected
    ])


    # --------------------------------------------------------
    # F. Fit all 16 points
    # --------------------------------------------------------

    (
        m,
        b,
        sigma_m,
        sigma_b,
        Y_fit,
        R2
    ) = linear_fit(
        E_all,
        Y_all
    )


    # --------------------------------------------------------
    # G. Calculate new temperature
    # --------------------------------------------------------

    T_new = temperature_from_slope(
        m
    )


    # --------------------------------------------------------
    # H. Temperature uncertainty
    #
    # Relative error:
    #
    # sigma_T/T = sigma_m/|m|
    # --------------------------------------------------------

    sigma_T_new = temperature_uncertainty(
        T_new,
        m,
        sigma_m
    )


    # --------------------------------------------------------
    # I. Save results
    # --------------------------------------------------------

    results.append([
        iteration,
        T,
        sigma_T,
        omega,
        sigma_omega,
        Ne,
        sigma_Ne,
        saha,
        m,
        sigma_m,
        T_new,
        sigma_T_new,
        R2,
        sigma_saha
    ])


    # ========================================================
    # J. PRINT CURRENT ITERATION
    # ========================================================

    print()
    print("=" * 100)
    print(f"ITERATION {iteration}")
    print("=" * 100)

    print(
        f"T input = "
        f"{T:.3f} +/- {sigma_T:.3f} K"
    )

    print(
        f"omega = "
        f"{omega:.9e} +/- "
        f"{sigma_omega:.9e} nm"
    )

    print(
        f"Ne = "
        f"{Ne:.6e} +/- "
        f"{sigma_Ne:.6e} cm^-3"
    )

    print(
        f"Relative Ne uncertainty = "
        f"{relative_Ne_error*100:.3f} %"
    )

    print(
        f"Saha correction = "
        f"{saha:.6f} +/- {sigma_saha:.6f}"
    )

    print(
        f"Slope = "
        f"{m:.9e} +/- "
        f"{sigma_m:.9e} cm"
    )

    print(
        f"Relative slope uncertainty = "
        f"{sigma_m/abs(m)*100:.3f} %"
    )

    print(
        f"T output = "
        f"{T_new:.3f} +/- "
        f"{sigma_T_new:.3f} K"
    )

    print(
        f"Relative temperature uncertainty = "
        f"{sigma_T_new/T_new*100:.3f} %"
    )

    print(
        f"R^2 = {R2:.6f}"
    )

    print()
    print("UNCERTAINTY PROPAGATION FOR THIS ITERATION")
    print("Ca I:  Delta y = DeltaI/I + Deltalambda/lambda + DeltaA/A")
    print("Ca II: Delta y = DeltaI/I + Deltalambda/lambda + DeltaA/A + DeltaS/S")
    print(f"DeltaS/S = {relative_S_error:.6f} ({relative_S_error*100:.3f} %)" )

    print()
    print("Ca II line-by-line y-error bars")
    print("-" * 110)
    print(f"{'lambda(nm)':>11} | {'dI/I':>10} | {'dl/l':>10} | {'dA/A':>10} | {'dS/S':>10} | {'dy':>10} | {'Y':>10} | {'Y +/- dy':>18}")
    print("-" * 110)
    for i in range(6):
        print(
            f"{wavelength_CaII_nm[i]:11.2f} | "
            f"{deltaI_over_I_CaII[i]:10.6f} | "
            f"{deltaLambda_over_lambda_CaII[i]:10.7f} | "
            f"{deltaA_over_A_CaII[i]:10.2f} | "
            f"{relative_S_error:10.6f} | "
            f"{sigma_Y_CaII_corrected[i]:10.6f} | "
            f"{Y_CaII_corrected[i]:10.5f} | "
            f"{Y_CaII_corrected[i]:10.5f} +/- {sigma_Y_CaII_corrected[i]:.5f}"
        )

    print()
    print("Ca I line-by-line y-error bars")
    print("-" * 95)
    print(f"{'lambda(nm)':>11} | {'grade':>5} | {'dI/I':>10} | {'dl/l':>10} | {'dA/A':>10} | {'dy':>10} | {'Y':>10}")
    print("-" * 95)
    for i in range(10):
        print(
            f"{wavelength_CaI_nm[i]:11.2f} | "
            f"{grade_CaI[i]:>5} | "
            f"{deltaI_over_I_CaI[i]:10.6f} | "
            f"{deltaLambda_over_lambda_CaI[i]:10.7f} | "
            f"{deltaA_over_A_CaI[i]:10.2f} | "
            f"{sigma_Y_CaI[i]:10.6f} | "
            f"{Y_CaI[i]:10.5f}"
        )


    # ========================================================
    # K. PRINT CORRECTED Ca II VALUES
    # ========================================================

    print()
    print("Ca II Saha-corrected Y values")
    print("-" * 70)

    for i in range(6):

        print(
            f"{i+1:2d}. "
            f"E = {E_CaII[i]:.0f} cm^-1   "
            f"Raw Y = {Y_CaII_raw[i]:.5f}   "
            f"Corrected Y = "
            f"{Y_CaII_corrected[i]:.5f}"
        )


    # ========================================================
    # L. DRAW BOLTZMANN PLOT FOR THIS ITERATION
    #
    # The Ca I dataset is unchanged during Saha iterations, so
    # this plot is mathematically identical to the initial Ca I
    # Boltzmann plot; it is redrawn here deliberately so every
    # iteration has a complete, self-contained plot and summary.
    # ========================================================

    plt.figure(figsize=(9, 6))
    plt.errorbar(
        E_CaI,
        Y_CaI,
        yerr=sigma_Y_CaI,
        fmt="o",
        markersize=7,
        capsize=4,
        elinewidth=1.2,
        ecolor="black",
        label=r"Ca I ($\pm\Delta y$)",
        zorder=3
    )

    E_line_CaI = np.linspace(E_CaI.min() - 500, E_CaI.max() + 500, 500)
    Y_line_CaI = m_initial * E_line_CaI + b_initial
    Y_low_CaI, Y_high_CaI = fit_uncertainty_band(
        E_line_CaI, m_initial, sigma_m_initial, b_initial, sigma_b_initial
    )
    plt.fill_between(E_line_CaI, Y_low_CaI, Y_high_CaI, alpha=0.15, label="Fit uncertainty")
    plt.plot(E_line_CaI, Y_line_CaI, linewidth=2, label="Ca I linear fit")
    plt.xlabel(r"Upper-level energy $E_k$ (cm$^{-1}$)")
    plt.ylabel("Boltzmann Y-coordinate")
    plt.title(f"Boltzmann Plot — Ca I — Iteration {iteration}")
    plt.text(
        0.02, 0.97,
        f"Iteration = {iteration}\nT(Ca I) = {T_initial:.2f} ± {sigma_T_initial:.2f} K\nR² = {R2_initial:.5f}",
        transform=plt.gca().transAxes, ha="left", va="top",
        bbox=dict(facecolor="white", edgecolor="black", alpha=0.9)
    )
    plt.grid(alpha=0.3)
    plt.legend()
    plt.tight_layout()
    plt.show()


    # ========================================================
    # M. DRAW SAHA-BOLTZMANN PLOT
    # ========================================================

    plt.figure(
        figsize=(10, 6.5)
    )


    # Regression line + worst-case fit uncertainty band
    E_plot = np.linspace(
        E_all.min() - 1000,
        E_all.max() + 1000,
        500
    )

    Y_plot = (
        m * E_plot
        +
        b
    )

    Y_plot_lower, Y_plot_upper = fit_uncertainty_band(
        E_plot,
        m,
        sigma_m,
        b,
        sigma_b
    )

    plt.fill_between(
        E_plot,
        Y_plot_lower,
        Y_plot_upper,
        alpha=0.15,
        color="gray",
        label="Fit uncertainty (worst case)",
        zorder=1
    )

    plt.plot(
        E_plot,
        Y_plot,
        linewidth=2.5,
        label="16-line fit",
        zorder=2
    )


    # Ca I — propagated line-by-line y-error bars
    plt.errorbar(
        E_CaI,
        Y_CaI,
        yerr=sigma_Y_CaI,
        fmt="o",
        markersize=7,
        capsize=4,
        elinewidth=1.2,
        ecolor="black",
        label=r"Ca I ($\pm\Delta y$, linear relative-error propagation)",
        zorder=3
    )


    # Ca II  — y-error bars from the propagated Saha-correction
    # uncertainty (sigma_saha), calculated from sigma_T and sigma_Ne
    plt.errorbar(
        E_CaII,
        Y_CaII_corrected,
        yerr=sigma_Y_CaII_corrected,
        fmt="s",
        markersize=8,
        capsize=4,
        elinewidth=1.5,
        color="tab:orange",
        ecolor="black",
        label="Ca II — Saha corrected (±Δy, linear propagation)",
        zorder=4
    )


    plt.xlabel(
        r"Upper-level energy $E_k$ (cm$^{-1}$)",
        fontsize=12
    )

    plt.ylabel(
        "Saha-Boltzmann Y-coordinate",
        fontsize=12
    )

    plt.title(
        f"Saha-Boltzmann Plot — Iteration {iteration}",
        fontsize=14
    )


    # Information box away from data
    information = (
        f"Iteration = {iteration}\n"
        f"T = {T_new:.2f} ± {sigma_T_new:.2f} K\n"
        f"Ne = {Ne:.3e} ± {sigma_Ne:.2e} cm$^{{-3}}$\n"
        f"Slope = {m:.3e} ± {sigma_m:.2e} cm\n"
        f"Saha = {saha:.5f} ± {sigma_saha:.5f}\n"
        f"R² = {R2:.5f}"
    )


    plt.text(
        0.02,
        0.97,
        information,
        transform=plt.gca().transAxes,
        ha="left",
        va="top",
        fontsize=9,
        bbox=dict(
            facecolor="white",
            edgecolor="black",
            alpha=0.9
        )
    )


    plt.grid(alpha=0.3)
    plt.legend()
    plt.tight_layout()
    plt.show()


    # ========================================================
    # M. CHECK CONVERGENCE
    # ========================================================

    temperature_change = abs(
        T_new - T
    )

    print(
        f"\nTemperature change = "
        f"{temperature_change:.6f} K"
    )


    if temperature_change < tolerance:

        print()
        print("*" * 100)
        print("CONVERGENCE ACHIEVED")
        print("*" * 100)

        print(
            f"Final temperature = "
            f"{T_new:.3f} +/- "
            f"{sigma_T_new:.3f} K"
        )

        print(
            f"Final electron density = "
            f"{Ne:.6e} +/- "
            f"{sigma_Ne:.6e} cm^-3"
        )

        break


    # --------------------------------------------------------
    # Update temperature and uncertainty
    # --------------------------------------------------------

    T = T_new
    sigma_T = sigma_T_new


# ============================================================
# 17. FINAL ITERATION TABLE
# ============================================================

print()
print()
print("=" * 175)
print("FINAL SAHA-BOLTZMANN ITERATION TABLE")
print("=" * 175)


print(
    f"{'Iter':>4} | "
    f"{'T_in':>11} | "
    f"{'σT_in':>10} | "
    f"{'omega':>12} | "
    f"{'Ne':>15} | "
    f"{'σNe':>15} | "
    f"{'Saha':>9} | "
    f"{'σSaha':>9} | "
    f"{'Slope':>14} | "
    f"{'σSlope':>13} | "
    f"{'T_out':>11} | "
    f"{'σT_out':>10}"
)

print("-" * 175)


for row in results:

    (
        iteration,
        T_in,
        sigma_T_in,
        omega,
        sigma_omega,
        Ne,
        sigma_Ne,
        saha,
        m,
        sigma_m,
        T_out,
        sigma_T_out,
        R2,
        sigma_saha
    ) = row


    print(
        f"{iteration:4d} | "
        f"{T_in:11.3f} | "
        f"{sigma_T_in:10.3f} | "
        f"{omega:12.8e} | "
        f"{Ne:15.6e} | "
        f"{sigma_Ne:15.6e} | "
        f"{saha:9.5f} | "
        f"{sigma_saha:9.5f} | "
        f"{m:14.6e} | "
        f"{sigma_m:13.6e} | "
        f"{T_out:11.3f} | "
        f"{sigma_T_out:10.3f}"
    )


print("=" * 175)


# ============================================================
# 18. FINAL RESULT
# ============================================================

final = results[-1]


final_T = final[10]
final_sigma_T = final[11]

final_Ne = final[5]
final_sigma_Ne = final[6]

final_m = final[8]
final_sigma_m = final[9]

final_omega = final[3]
final_sigma_omega = final[4]

final_saha = final[7]
final_sigma_saha = final[13]


print()
print("=" * 100)
print("FINAL RESULTS")
print("=" * 100)

print(
    f"Initial Ca I temperature = "
    f"{T_initial:.3f} +/- "
    f"{sigma_T_initial:.3f} K"
)

print(
    f"Final slope = "
    f"{final_m:.9e} +/- "
    f"{final_sigma_m:.9e} cm"
)

print(
    f"Final temperature = "
    f"{final_T:.3f} +/- "
    f"{final_sigma_T:.3f} K"
)

print(
    f"Final omega = "
    f"{final_omega:.9e} +/- "
    f"{final_sigma_omega:.9e} nm"
)

print(
    f"Final electron density = "
    f"{final_Ne:.6e} +/- "
    f"{final_sigma_Ne:.6e} cm^-3"
)

print(
    f"Final Saha correction = "
    f"{final_saha:.6f} +/- {final_sigma_saha:.6f}"
)

print("=" * 100)


# ============================================================
# 19. UNCERTAINTY SUMMARY
# ============================================================

print()
print("=" * 100)
print("UNCERTAINTY SUMMARY")
print("=" * 100)

print(
    f"Stark width = "
    f"{delta_lambda:.3f} +/- "
    f"{sigma_delta_lambda:.3f} nm"
)

print(
    f"Relative Stark-width uncertainty = "
    f"{sigma_delta_lambda/delta_lambda*100:.3f} %"
)

print(
    f"Final relative slope uncertainty = "
    f"{final_sigma_m/abs(final_m)*100:.3f} %"
)

print(
    f"Final relative temperature uncertainty = "
    f"{final_sigma_T/final_T*100:.3f} %"
)

print(
    f"Final relative electron-density uncertainty = "
    f"{final_sigma_Ne/final_Ne*100:.3f} %"
)

print(
    f"Final Saha relative uncertainty (DeltaS/S) = "
    f"{final_sigma_saha:.5f} "
    f"(common Saha contribution; line-specific Ca II Delta y also includes dI/I, dl/l and dA/A)"
)

print("=" * 100)
# Out:
# ==========================================================================================
# INITIAL Ca I BOLTZMANN PLOT
# ==========================================================================================
# Slope = -1.972866773e-04 +/- 5.415449789e-05 cm
# Relative slope uncertainty = 27.450 %
# Temperature = 7292.823 +/- 2001.854 K
# Relative temperature uncertainty = 27.450 %
# R^2 = 0.623913
# ==========================================================================================
# ====================================================================================================
# ITERATION 0
# ====================================================================================================
# T input = 7292.823 +/- 2001.854 K
# omega = 5.973379961e-04 +/- 3.819419272e-05 nm
# Ne = 2.092618e+18 +/- 2.057894e+17 cm^-3
# Relative Ne uncertainty = 9.834 %
# Saha correction = 7.270513 +/- 0.510085
# Slope = -1.441117143e-04 +/- 1.154288946e-05 cm
# Relative slope uncertainty = 8.010 %
# T output = 9983.761 +/- 799.667 K
# Relative temperature uncertainty = 8.010 %
# R^2 = 0.917585
#
# UNCERTAINTY PROPAGATION FOR THIS ITERATION
# Ca I:  Delta y = DeltaI/I + Deltalambda/lambda + DeltaA/A
# Ca II: Delta y = DeltaI/I + Deltalambda/lambda + DeltaA/A + DeltaS/S
# DeltaS/S = 0.510085 (51.009 %)
#
# Ca II line-by-line y-error bars
# --------------------------------------------------------------------------------------------------------------
#  lambda(nm) |       dI/I |       dl/l |       dA/A |       dS/S |         dy |          Y |           Y +/- dy
# --------------------------------------------------------------------------------------------------------------
#      315.89 |   0.000305 |  0.0001583 |       0.25 |   0.510085 |   0.760548 |   24.81949 |   24.81949 +/- 0.76055
#      317.93 |   0.000305 |  0.0001573 |       0.25 |   0.510085 |   0.760547 |   24.21949 |   24.21949 +/- 0.76055
#      370.60 |   0.000805 |  0.0001349 |       0.25 |   0.510085 |   0.761025 |   26.86949 |   26.86949 +/- 0.76102
#      373.69 |   0.000805 |  0.0001338 |       0.25 |   0.510085 |   0.761024 |   26.24949 |   26.24949 +/- 0.76102
#      393.36 |   0.000805 |  0.0001271 |       0.25 |   0.510085 |   0.761017 |   25.74949 |   25.74949 +/- 0.76102
#      396.85 |   0.000805 |  0.0001260 |       0.25 |   0.510085 |   0.761016 |   26.49949 |   26.49949 +/- 0.76102
#
# Ca I line-by-line y-error bars
# -----------------------------------------------------------------------------------------------
#  lambda(nm) | grade |       dI/I |       dl/l |       dA/A |         dy |          Y
# -----------------------------------------------------------------------------------------------
#      458.14 |     C |   0.004887 |  0.0001091 |       0.25 |   0.254996 |   32.88000
#      458.58 |     C |   0.005962 |  0.0001090 |       0.25 |   0.256071 |   32.65000
#      526.17 |     D |   0.001515 |  0.0000950 |       0.50 |   0.501610 |   35.07000
#      558.19 |     D |   0.003290 |  0.0000896 |       0.50 |   0.503379 |   34.80000
#      560.28 |     D |   0.003197 |  0.0000892 |       0.50 |   0.503287 |   34.85000
#      610.27 |     C |   0.001359 |  0.0000819 |       0.25 |   0.251441 |   35.97000
#      612.22 |     C |   0.000025 |  0.0000817 |       0.25 |   0.250107 |   35.23000
#      616.21 |     C |   0.001152 |  0.0000811 |       0.25 |   0.251233 |   34.88000
#      616.95 |     D |   0.000663 |  0.0000810 |       0.50 |   0.500744 |   34.82000
#      445.58 |     C |   0.000101 |  0.0001122 |       0.25 |   0.250213 |   34.48000
#
# Ca II Saha-corrected Y values
# ----------------------------------------------------------------------
#  1. E = 106139 cm^-1   Raw Y = 32.09000   Corrected Y = 24.81949
#  2. E = 106158 cm^-1   Raw Y = 31.49000   Corrected Y = 24.21949
#  3. E = 101466 cm^-1   Raw Y = 34.14000   Corrected Y = 26.86949
#  4. E = 101466 cm^-1   Raw Y = 33.52000   Corrected Y = 26.24949
#  5. E = 74714 cm^-1   Raw Y = 33.02000   Corrected Y = 25.74949
#  6. E = 74491 cm^-1   Raw Y = 33.77000   Corrected Y = 26.49949
# Temperature change = 2690.937494 K
#
# ====================================================================================================
# ITERATION 1
# ====================================================================================================
# T input = 9983.761 +/- 799.667 K
# omega = 6.328408708e-04 +/- 1.605220498e-05 nm
# Ne = 1.975220e+18 +/- 1.180496e+17 cm^-3
# Relative Ne uncertainty = 5.977 %
# Saha correction = 7.799353 +/- 0.179911
# Slope = -1.524685757e-04 +/- 1.208717969e-05 cm
# Relative slope uncertainty = 7.928 %
# T output = 9436.547 +/- 748.097 K
# Relative temperature uncertainty = 7.928 %
# R^2 = 0.919129
#
# UNCERTAINTY PROPAGATION FOR THIS ITERATION
# Ca I:  Delta y = DeltaI/I + Deltalambda/lambda + DeltaA/A
# Ca II: Delta y = DeltaI/I + Deltalambda/lambda + DeltaA/A + DeltaS/S
# DeltaS/S = 0.179911 (17.991 %)
#
# Ca II line-by-line y-error bars
# --------------------------------------------------------------------------------------------------------------
#  lambda(nm) |       dI/I |       dl/l |       dA/A |       dS/S |         dy |          Y |           Y +/- dy
# --------------------------------------------------------------------------------------------------------------
#      315.89 |   0.000305 |  0.0001583 |       0.25 |   0.179911 |   0.430373 |   24.29065 |   24.29065 +/- 0.43037
#      317.93 |   0.000305 |  0.0001573 |       0.25 |   0.179911 |   0.430372 |   23.69065 |   23.69065 +/- 0.43037
#      370.60 |   0.000805 |  0.0001349 |       0.25 |   0.179911 |   0.430850 |   26.34065 |   26.34065 +/- 0.43085
#      373.69 |   0.000805 |  0.0001338 |       0.25 |   0.179911 |   0.430849 |   25.72065 |   25.72065 +/- 0.43085
#      393.36 |   0.000805 |  0.0001271 |       0.25 |   0.179911 |   0.430842 |   25.22065 |   25.22065 +/- 0.43084
#      396.85 |   0.000805 |  0.0001260 |       0.25 |   0.179911 |   0.430841 |   25.97065 |   25.97065 +/- 0.43084
#
# Ca I line-by-line y-error bars
# -----------------------------------------------------------------------------------------------
#  lambda(nm) | grade |       dI/I |       dl/l |       dA/A |         dy |          Y
# -----------------------------------------------------------------------------------------------
#      458.14 |     C |   0.004887 |  0.0001091 |       0.25 |   0.254996 |   32.88000
#      458.58 |     C |   0.005962 |  0.0001090 |       0.25 |   0.256071 |   32.65000
#      526.17 |     D |   0.001515 |  0.0000950 |       0.50 |   0.501610 |   35.07000
#      558.19 |     D |   0.003290 |  0.0000896 |       0.50 |   0.503379 |   34.80000
#      560.28 |     D |   0.003197 |  0.0000892 |       0.50 |   0.503287 |   34.85000
#      610.27 |     C |   0.001359 |  0.0000819 |       0.25 |   0.251441 |   35.97000
#      612.22 |     C |   0.000025 |  0.0000817 |       0.25 |   0.250107 |   35.23000
#      616.21 |     C |   0.001152 |  0.0000811 |       0.25 |   0.251233 |   34.88000
#      616.95 |     D |   0.000663 |  0.0000810 |       0.50 |   0.500744 |   34.82000
#      445.58 |     C |   0.000101 |  0.0001122 |       0.25 |   0.250213 |   34.48000
#
# Ca II Saha-corrected Y values
# ----------------------------------------------------------------------
#  1. E = 106139 cm^-1   Raw Y = 32.09000   Corrected Y = 24.29065
#  2. E = 106158 cm^-1   Raw Y = 31.49000   Corrected Y = 23.69065
#  3. E = 101466 cm^-1   Raw Y = 34.14000   Corrected Y = 26.34065
#  4. E = 101466 cm^-1   Raw Y = 33.52000   Corrected Y = 25.72065
#  5. E = 74714 cm^-1   Raw Y = 33.02000   Corrected Y = 25.22065
#  6. E = 74491 cm^-1   Raw Y = 33.77000   Corrected Y = 25.97065
# Temperature change = 547.213785 K
#
# ====================================================================================================
# ITERATION 2
# ====================================================================================================
# T input = 9436.547 +/- 748.097 K
# omega = 6.258379097e-04 +/- 1.486574906e-05 nm
# Ne = 1.997322e+18 +/- 1.161510e+17 cm^-3
# Relative Ne uncertainty = 5.815 %
# Saha correction = 7.703671 +/- 0.177068
# Slope = -1.509565808e-04 +/- 1.198723408e-05 cm
# Relative slope uncertainty = 7.941 %
# T output = 9531.064 +/- 756.847 K
# Relative temperature uncertainty = 7.941 %
# R^2 = 0.918881
#
# UNCERTAINTY PROPAGATION FOR THIS ITERATION
# Ca I:  Delta y = DeltaI/I + Deltalambda/lambda + DeltaA/A
# Ca II: Delta y = DeltaI/I + Deltalambda/lambda + DeltaA/A + DeltaS/S
# DeltaS/S = 0.177068 (17.707 %)
#
# Ca II line-by-line y-error bars
# --------------------------------------------------------------------------------------------------------------
#  lambda(nm) |       dI/I |       dl/l |       dA/A |       dS/S |         dy |          Y |           Y +/- dy
# --------------------------------------------------------------------------------------------------------------
#      315.89 |   0.000305 |  0.0001583 |       0.25 |   0.177068 |   0.427531 |   24.38633 |   24.38633 +/- 0.42753
#      317.93 |   0.000305 |  0.0001573 |       0.25 |   0.177068 |   0.427530 |   23.78633 |   23.78633 +/- 0.42753
#      370.60 |   0.000805 |  0.0001349 |       0.25 |   0.177068 |   0.428008 |   26.43633 |   26.43633 +/- 0.42801
#      373.69 |   0.000805 |  0.0001338 |       0.25 |   0.177068 |   0.428007 |   25.81633 |   25.81633 +/- 0.42801
#      393.36 |   0.000805 |  0.0001271 |       0.25 |   0.177068 |   0.428000 |   25.31633 |   25.31633 +/- 0.42800
#      396.85 |   0.000805 |  0.0001260 |       0.25 |   0.177068 |   0.427999 |   26.06633 |   26.06633 +/- 0.42800
#
# Ca I line-by-line y-error bars
# -----------------------------------------------------------------------------------------------
#  lambda(nm) | grade |       dI/I |       dl/l |       dA/A |         dy |          Y
# -----------------------------------------------------------------------------------------------
#      458.14 |     C |   0.004887 |  0.0001091 |       0.25 |   0.254996 |   32.88000
#      458.58 |     C |   0.005962 |  0.0001090 |       0.25 |   0.256071 |   32.65000
#      526.17 |     D |   0.001515 |  0.0000950 |       0.50 |   0.501610 |   35.07000
#      558.19 |     D |   0.003290 |  0.0000896 |       0.50 |   0.503379 |   34.80000
#      560.28 |     D |   0.003197 |  0.0000892 |       0.50 |   0.503287 |   34.85000
#      610.27 |     C |   0.001359 |  0.0000819 |       0.25 |   0.251441 |   35.97000
#      612.22 |     C |   0.000025 |  0.0000817 |       0.25 |   0.250107 |   35.23000
#      616.21 |     C |   0.001152 |  0.0000811 |       0.25 |   0.251233 |   34.88000
#      616.95 |     D |   0.000663 |  0.0000810 |       0.50 |   0.500744 |   34.82000
#      445.58 |     C |   0.000101 |  0.0001122 |       0.25 |   0.250213 |   34.48000
#
# Ca II Saha-corrected Y values
# ----------------------------------------------------------------------
#  1. E = 106139 cm^-1   Raw Y = 32.09000   Corrected Y = 24.38633
#  2. E = 106158 cm^-1   Raw Y = 31.49000   Corrected Y = 23.78633
#  3. E = 101466 cm^-1   Raw Y = 34.14000   Corrected Y = 26.43633
#  4. E = 101466 cm^-1   Raw Y = 33.52000   Corrected Y = 25.81633
#  5. E = 74714 cm^-1   Raw Y = 33.02000   Corrected Y = 25.31633
#  6. E = 74491 cm^-1   Raw Y = 33.77000   Corrected Y = 26.06633
# Temperature change = 94.517319 K
#
# ====================================================================================================
# ITERATION 3
# ====================================================================================================
# T input = 9531.064 +/- 756.847 K
# omega = 6.270553980e-04 +/- 1.506606767e-05 nm
# Ne = 1.993444e+18 +/- 1.164704e+17 cm^-3
# Relative Ne uncertainty = 5.843 %
# Saha correction = 7.720564 +/- 0.177539
# Slope = -1.512235265e-04 +/- 1.200483436e-05 cm
# Relative slope uncertainty = 7.938 %
# T output = 9514.240 +/- 755.285 K
# Relative temperature uncertainty = 7.938 %
# R^2 = 0.918926
#
# UNCERTAINTY PROPAGATION FOR THIS ITERATION
# Ca I:  Delta y = DeltaI/I + Deltalambda/lambda + DeltaA/A
# Ca II: Delta y = DeltaI/I + Deltalambda/lambda + DeltaA/A + DeltaS/S
# DeltaS/S = 0.177539 (17.754 %)
#
# Ca II line-by-line y-error bars
# --------------------------------------------------------------------------------------------------------------
#  lambda(nm) |       dI/I |       dl/l |       dA/A |       dS/S |         dy |          Y |           Y +/- dy
# --------------------------------------------------------------------------------------------------------------
#      315.89 |   0.000305 |  0.0001583 |       0.25 |   0.177539 |   0.428002 |   24.36944 |   24.36944 +/- 0.42800
#      317.93 |   0.000305 |  0.0001573 |       0.25 |   0.177539 |   0.428001 |   23.76944 |   23.76944 +/- 0.42800
#      370.60 |   0.000805 |  0.0001349 |       0.25 |   0.177539 |   0.428479 |   26.41944 |   26.41944 +/- 0.42848
#      373.69 |   0.000805 |  0.0001338 |       0.25 |   0.177539 |   0.428478 |   25.79944 |   25.79944 +/- 0.42848
#      393.36 |   0.000805 |  0.0001271 |       0.25 |   0.177539 |   0.428471 |   25.29944 |   25.29944 +/- 0.42847
#      396.85 |   0.000805 |  0.0001260 |       0.25 |   0.177539 |   0.428470 |   26.04944 |   26.04944 +/- 0.42847
#
# Ca I line-by-line y-error bars
# -----------------------------------------------------------------------------------------------
#  lambda(nm) | grade |       dI/I |       dl/l |       dA/A |         dy |          Y
# -----------------------------------------------------------------------------------------------
#      458.14 |     C |   0.004887 |  0.0001091 |       0.25 |   0.254996 |   32.88000
#      458.58 |     C |   0.005962 |  0.0001090 |       0.25 |   0.256071 |   32.65000
#      526.17 |     D |   0.001515 |  0.0000950 |       0.50 |   0.501610 |   35.07000
#      558.19 |     D |   0.003290 |  0.0000896 |       0.50 |   0.503379 |   34.80000
#      560.28 |     D |   0.003197 |  0.0000892 |       0.50 |   0.503287 |   34.85000
#      610.27 |     C |   0.001359 |  0.0000819 |       0.25 |   0.251441 |   35.97000
#      612.22 |     C |   0.000025 |  0.0000817 |       0.25 |   0.250107 |   35.23000
#      616.21 |     C |   0.001152 |  0.0000811 |       0.25 |   0.251233 |   34.88000
#      616.95 |     D |   0.000663 |  0.0000810 |       0.50 |   0.500744 |   34.82000
#      445.58 |     C |   0.000101 |  0.0001122 |       0.25 |   0.250213 |   34.48000
#
# Ca II Saha-corrected Y values
# ----------------------------------------------------------------------
#  1. E = 106139 cm^-1   Raw Y = 32.09000   Corrected Y = 24.36944
#  2. E = 106158 cm^-1   Raw Y = 31.49000   Corrected Y = 23.76944
#  3. E = 101466 cm^-1   Raw Y = 34.14000   Corrected Y = 26.41944
#  4. E = 101466 cm^-1   Raw Y = 33.52000   Corrected Y = 25.79944
#  5. E = 74714 cm^-1   Raw Y = 33.02000   Corrected Y = 25.29944
#  6. E = 74491 cm^-1   Raw Y = 33.77000   Corrected Y = 26.04944
# Temperature change = 16.824609 K
#
# ====================================================================================================
# ITERATION 4
# ====================================================================================================
# T input = 9514.240 +/- 755.285 K
# omega = 6.268389198e-04 +/- 1.503027208e-05 nm
# Ne = 1.994133e+18 +/- 1.164133e+17 cm^-3
# Relative Ne uncertainty = 5.838 %
# Saha correction = 7.717568 +/- 0.177455
# Slope = -1.511761910e-04 +/- 1.200171201e-05 cm
# Relative slope uncertainty = 7.939 %
# T output = 9517.219 +/- 755.562 K
# Relative temperature uncertainty = 7.939 %
# R^2 = 0.918918
#
# UNCERTAINTY PROPAGATION FOR THIS ITERATION
# Ca I:  Delta y = DeltaI/I + Deltalambda/lambda + DeltaA/A
# Ca II: Delta y = DeltaI/I + Deltalambda/lambda + DeltaA/A + DeltaS/S
# DeltaS/S = 0.177455 (17.745 %)
#
# Ca II line-by-line y-error bars
# --------------------------------------------------------------------------------------------------------------
#  lambda(nm) |       dI/I |       dl/l |       dA/A |       dS/S |         dy |          Y |           Y +/- dy
# --------------------------------------------------------------------------------------------------------------
#      315.89 |   0.000305 |  0.0001583 |       0.25 |   0.177455 |   0.427918 |   24.37243 |   24.37243 +/- 0.42792
#      317.93 |   0.000305 |  0.0001573 |       0.25 |   0.177455 |   0.427917 |   23.77243 |   23.77243 +/- 0.42792
#      370.60 |   0.000805 |  0.0001349 |       0.25 |   0.177455 |   0.428394 |   26.42243 |   26.42243 +/- 0.42839
#      373.69 |   0.000805 |  0.0001338 |       0.25 |   0.177455 |   0.428393 |   25.80243 |   25.80243 +/- 0.42839
#      393.36 |   0.000805 |  0.0001271 |       0.25 |   0.177455 |   0.428387 |   25.30243 |   25.30243 +/- 0.42839
#      396.85 |   0.000805 |  0.0001260 |       0.25 |   0.177455 |   0.428385 |   26.05243 |   26.05243 +/- 0.42839
#
# Ca I line-by-line y-error bars
# -----------------------------------------------------------------------------------------------
#  lambda(nm) | grade |       dI/I |       dl/l |       dA/A |         dy |          Y
# -----------------------------------------------------------------------------------------------
#      458.14 |     C |   0.004887 |  0.0001091 |       0.25 |   0.254996 |   32.88000
#      458.58 |     C |   0.005962 |  0.0001090 |       0.25 |   0.256071 |   32.65000
#      526.17 |     D |   0.001515 |  0.0000950 |       0.50 |   0.501610 |   35.07000
#      558.19 |     D |   0.003290 |  0.0000896 |       0.50 |   0.503379 |   34.80000
#      560.28 |     D |   0.003197 |  0.0000892 |       0.50 |   0.503287 |   34.85000
#      610.27 |     C |   0.001359 |  0.0000819 |       0.25 |   0.251441 |   35.97000
#      612.22 |     C |   0.000025 |  0.0000817 |       0.25 |   0.250107 |   35.23000
#      616.21 |     C |   0.001152 |  0.0000811 |       0.25 |   0.251233 |   34.88000
#      616.95 |     D |   0.000663 |  0.0000810 |       0.50 |   0.500744 |   34.82000
#      445.58 |     C |   0.000101 |  0.0001122 |       0.25 |   0.250213 |   34.48000
#
# Ca II Saha-corrected Y values
# ----------------------------------------------------------------------
#  1. E = 106139 cm^-1   Raw Y = 32.09000   Corrected Y = 24.37243
#  2. E = 106158 cm^-1   Raw Y = 31.49000   Corrected Y = 23.77243
#  3. E = 101466 cm^-1   Raw Y = 34.14000   Corrected Y = 26.42243
#  4. E = 101466 cm^-1   Raw Y = 33.52000   Corrected Y = 25.80243
#  5. E = 74714 cm^-1   Raw Y = 33.02000   Corrected Y = 25.30243
#  6. E = 74491 cm^-1   Raw Y = 33.77000   Corrected Y = 26.05243
# Temperature change = 2.979049 K
#
# ====================================================================================================
# ITERATION 5
# ====================================================================================================
# T input = 9517.219 +/- 755.562 K
# omega = 6.268772581e-04 +/- 1.503660586e-05 nm
# Ne = 1.994011e+18 +/- 1.164234e+17 cm^-3
# Relative Ne uncertainty = 5.839 %
# Saha correction = 7.718099 +/- 0.177470
# Slope = -1.511845782e-04 +/- 1.200226520e-05 cm
# Relative slope uncertainty = 7.939 %
# T output = 9516.691 +/- 755.513 K
# Relative temperature uncertainty = 7.939 %
# R^2 = 0.918919
#
# UNCERTAINTY PROPAGATION FOR THIS ITERATION
# Ca I:  Delta y = DeltaI/I + Deltalambda/lambda + DeltaA/A
# Ca II: Delta y = DeltaI/I + Deltalambda/lambda + DeltaA/A + DeltaS/S
# DeltaS/S = 0.177470 (17.747 %)
#
# Ca II line-by-line y-error bars
# --------------------------------------------------------------------------------------------------------------
#  lambda(nm) |       dI/I |       dl/l |       dA/A |       dS/S |         dy |          Y |           Y +/- dy
# --------------------------------------------------------------------------------------------------------------
#      315.89 |   0.000305 |  0.0001583 |       0.25 |   0.177470 |   0.427933 |   24.37190 |   24.37190 +/- 0.42793
#      317.93 |   0.000305 |  0.0001573 |       0.25 |   0.177470 |   0.427932 |   23.77190 |   23.77190 +/- 0.42793
#      370.60 |   0.000805 |  0.0001349 |       0.25 |   0.177470 |   0.428409 |   26.42190 |   26.42190 +/- 0.42841
#      373.69 |   0.000805 |  0.0001338 |       0.25 |   0.177470 |   0.428408 |   25.80190 |   25.80190 +/- 0.42841
#      393.36 |   0.000805 |  0.0001271 |       0.25 |   0.177470 |   0.428402 |   25.30190 |   25.30190 +/- 0.42840
#      396.85 |   0.000805 |  0.0001260 |       0.25 |   0.177470 |   0.428400 |   26.05190 |   26.05190 +/- 0.42840
#
# Ca I line-by-line y-error bars
# -----------------------------------------------------------------------------------------------
#  lambda(nm) | grade |       dI/I |       dl/l |       dA/A |         dy |          Y
# -----------------------------------------------------------------------------------------------
#      458.14 |     C |   0.004887 |  0.0001091 |       0.25 |   0.254996 |   32.88000
#      458.58 |     C |   0.005962 |  0.0001090 |       0.25 |   0.256071 |   32.65000
#      526.17 |     D |   0.001515 |  0.0000950 |       0.50 |   0.501610 |   35.07000
#      558.19 |     D |   0.003290 |  0.0000896 |       0.50 |   0.503379 |   34.80000
#      560.28 |     D |   0.003197 |  0.0000892 |       0.50 |   0.503287 |   34.85000
#      610.27 |     C |   0.001359 |  0.0000819 |       0.25 |   0.251441 |   35.97000
#      612.22 |     C |   0.000025 |  0.0000817 |       0.25 |   0.250107 |   35.23000
#      616.21 |     C |   0.001152 |  0.0000811 |       0.25 |   0.251233 |   34.88000
#      616.95 |     D |   0.000663 |  0.0000810 |       0.50 |   0.500744 |   34.82000
#      445.58 |     C |   0.000101 |  0.0001122 |       0.25 |   0.250213 |   34.48000
#
# Ca II Saha-corrected Y values
# ----------------------------------------------------------------------
#  1. E = 106139 cm^-1   Raw Y = 32.09000   Corrected Y = 24.37190
#  2. E = 106158 cm^-1   Raw Y = 31.49000   Corrected Y = 23.77190
#  3. E = 101466 cm^-1   Raw Y = 34.14000   Corrected Y = 26.42190
#  4. E = 101466 cm^-1   Raw Y = 33.52000   Corrected Y = 25.80190
#  5. E = 74714 cm^-1   Raw Y = 33.02000   Corrected Y = 25.30190
#  6. E = 74491 cm^-1   Raw Y = 33.77000   Corrected Y = 26.05190
# Temperature change = 0.527981 K
#
# ====================================================================================================
# ITERATION 6
# ====================================================================================================
# T input = 9516.691 +/- 755.513 K
# omega = 6.268704636e-04 +/- 1.503548318e-05 nm
# Ne = 1.994032e+18 +/- 1.164216e+17 cm^-3
# Relative Ne uncertainty = 5.838 %
# Saha correction = 7.718005 +/- 0.177467
# Slope = -1.511830919e-04 +/- 1.200216717e-05 cm
# Relative slope uncertainty = 7.939 %
# T output = 9516.784 +/- 755.521 K
# Relative temperature uncertainty = 7.939 %
# R^2 = 0.918919
#
# UNCERTAINTY PROPAGATION FOR THIS ITERATION
# Ca I:  Delta y = DeltaI/I + Deltalambda/lambda + DeltaA/A
# Ca II: Delta y = DeltaI/I + Deltalambda/lambda + DeltaA/A + DeltaS/S
# DeltaS/S = 0.177467 (17.747 %)
#
# Ca II line-by-line y-error bars
# --------------------------------------------------------------------------------------------------------------
#  lambda(nm) |       dI/I |       dl/l |       dA/A |       dS/S |         dy |          Y |           Y +/- dy
# --------------------------------------------------------------------------------------------------------------
#      315.89 |   0.000305 |  0.0001583 |       0.25 |   0.177467 |   0.427930 |   24.37200 |   24.37200 +/- 0.42793
#      317.93 |   0.000305 |  0.0001573 |       0.25 |   0.177467 |   0.427929 |   23.77200 |   23.77200 +/- 0.42793
#      370.60 |   0.000805 |  0.0001349 |       0.25 |   0.177467 |   0.428407 |   26.42200 |   26.42200 +/- 0.42841
#      373.69 |   0.000805 |  0.0001338 |       0.25 |   0.177467 |   0.428406 |   25.80200 |   25.80200 +/- 0.42841
#      393.36 |   0.000805 |  0.0001271 |       0.25 |   0.177467 |   0.428399 |   25.30200 |   25.30200 +/- 0.42840
#      396.85 |   0.000805 |  0.0001260 |       0.25 |   0.177467 |   0.428398 |   26.05200 |   26.05200 +/- 0.42840
#
# Ca I line-by-line y-error bars
# -----------------------------------------------------------------------------------------------
#  lambda(nm) | grade |       dI/I |       dl/l |       dA/A |         dy |          Y
# -----------------------------------------------------------------------------------------------
#      458.14 |     C |   0.004887 |  0.0001091 |       0.25 |   0.254996 |   32.88000
#      458.58 |     C |   0.005962 |  0.0001090 |       0.25 |   0.256071 |   32.65000
#      526.17 |     D |   0.001515 |  0.0000950 |       0.50 |   0.501610 |   35.07000
#      558.19 |     D |   0.003290 |  0.0000896 |       0.50 |   0.503379 |   34.80000
#      560.28 |     D |   0.003197 |  0.0000892 |       0.50 |   0.503287 |   34.85000
#      610.27 |     C |   0.001359 |  0.0000819 |       0.25 |   0.251441 |   35.97000
#      612.22 |     C |   0.000025 |  0.0000817 |       0.25 |   0.250107 |   35.23000
#      616.21 |     C |   0.001152 |  0.0000811 |       0.25 |   0.251233 |   34.88000
#      616.95 |     D |   0.000663 |  0.0000810 |       0.50 |   0.500744 |   34.82000
#      445.58 |     C |   0.000101 |  0.0001122 |       0.25 |   0.250213 |   34.48000
#
# Ca II Saha-corrected Y values
# ----------------------------------------------------------------------
#  1. E = 106139 cm^-1   Raw Y = 32.09000   Corrected Y = 24.37200
#  2. E = 106158 cm^-1   Raw Y = 31.49000   Corrected Y = 23.77200
#  3. E = 101466 cm^-1   Raw Y = 34.14000   Corrected Y = 26.42200
#  4. E = 101466 cm^-1   Raw Y = 33.52000   Corrected Y = 25.80200
#  5. E = 74714 cm^-1   Raw Y = 33.02000   Corrected Y = 25.30200
#  6. E = 74491 cm^-1   Raw Y = 33.77000   Corrected Y = 26.05200
# Temperature change = 0.093559 K
#
# ====================================================================================================
# ITERATION 7
# ====================================================================================================
# T input = 9516.784 +/- 755.521 K
# omega = 6.268716676e-04 +/- 1.503568212e-05 nm
# Ne = 1.994029e+18 +/- 1.164219e+17 cm^-3
# Relative Ne uncertainty = 5.839 %
# Saha correction = 7.718021 +/- 0.177468
# Slope = -1.511833552e-04 +/- 1.200218454e-05 cm
# Relative slope uncertainty = 7.939 %
# T output = 9516.768 +/- 755.520 K
# Relative temperature uncertainty = 7.939 %
# R^2 = 0.918919
#
# UNCERTAINTY PROPAGATION FOR THIS ITERATION
# Ca I:  Delta y = DeltaI/I + Deltalambda/lambda + DeltaA/A
# Ca II: Delta y = DeltaI/I + Deltalambda/lambda + DeltaA/A + DeltaS/S
# DeltaS/S = 0.177468 (17.747 %)
#
# Ca II line-by-line y-error bars
# --------------------------------------------------------------------------------------------------------------
#  lambda(nm) |       dI/I |       dl/l |       dA/A |       dS/S |         dy |          Y |           Y +/- dy
# --------------------------------------------------------------------------------------------------------------
#      315.89 |   0.000305 |  0.0001583 |       0.25 |   0.177468 |   0.427931 |   24.37198 |   24.37198 +/- 0.42793
#      317.93 |   0.000305 |  0.0001573 |       0.25 |   0.177468 |   0.427930 |   23.77198 |   23.77198 +/- 0.42793
#      370.60 |   0.000805 |  0.0001349 |       0.25 |   0.177468 |   0.428407 |   26.42198 |   26.42198 +/- 0.42841
#      373.69 |   0.000805 |  0.0001338 |       0.25 |   0.177468 |   0.428406 |   25.80198 |   25.80198 +/- 0.42841
#      393.36 |   0.000805 |  0.0001271 |       0.25 |   0.177468 |   0.428399 |   25.30198 |   25.30198 +/- 0.42840
#      396.85 |   0.000805 |  0.0001260 |       0.25 |   0.177468 |   0.428398 |   26.05198 |   26.05198 +/- 0.42840
#
# Ca I line-by-line y-error bars
# -----------------------------------------------------------------------------------------------
#  lambda(nm) | grade |       dI/I |       dl/l |       dA/A |         dy |          Y
# -----------------------------------------------------------------------------------------------
#      458.14 |     C |   0.004887 |  0.0001091 |       0.25 |   0.254996 |   32.88000
#      458.58 |     C |   0.005962 |  0.0001090 |       0.25 |   0.256071 |   32.65000
#      526.17 |     D |   0.001515 |  0.0000950 |       0.50 |   0.501610 |   35.07000
#      558.19 |     D |   0.003290 |  0.0000896 |       0.50 |   0.503379 |   34.80000
#      560.28 |     D |   0.003197 |  0.0000892 |       0.50 |   0.503287 |   34.85000
#      610.27 |     C |   0.001359 |  0.0000819 |       0.25 |   0.251441 |   35.97000
#      612.22 |     C |   0.000025 |  0.0000817 |       0.25 |   0.250107 |   35.23000
#      616.21 |     C |   0.001152 |  0.0000811 |       0.25 |   0.251233 |   34.88000
#      616.95 |     D |   0.000663 |  0.0000810 |       0.50 |   0.500744 |   34.82000
#      445.58 |     C |   0.000101 |  0.0001122 |       0.25 |   0.250213 |   34.48000
#
# Ca II Saha-corrected Y values
# ----------------------------------------------------------------------
#  1. E = 106139 cm^-1   Raw Y = 32.09000   Corrected Y = 24.37198
#  2. E = 106158 cm^-1   Raw Y = 31.49000   Corrected Y = 23.77198
#  3. E = 101466 cm^-1   Raw Y = 34.14000   Corrected Y = 26.42198
#  4. E = 101466 cm^-1   Raw Y = 33.52000   Corrected Y = 25.80198
#  5. E = 74714 cm^-1   Raw Y = 33.02000   Corrected Y = 25.30198
#  6. E = 74491 cm^-1   Raw Y = 33.77000   Corrected Y = 26.05198
# Temperature change = 0.016579 K
#
# ====================================================================================================
# ITERATION 8
# ====================================================================================================
# T input = 9516.768 +/- 755.520 K
# omega = 6.268714543e-04 +/- 1.503564686e-05 nm
# Ne = 1.994029e+18 +/- 1.164218e+17 cm^-3
# Relative Ne uncertainty = 5.839 %
# Saha correction = 7.718018 +/- 0.177468
# Slope = -1.511833086e-04 +/- 1.200218146e-05 cm
# Relative slope uncertainty = 7.939 %
# T output = 9516.771 +/- 755.520 K
# Relative temperature uncertainty = 7.939 %
# R^2 = 0.918919
#
# UNCERTAINTY PROPAGATION FOR THIS ITERATION
# Ca I:  Delta y = DeltaI/I + Deltalambda/lambda + DeltaA/A
# Ca II: Delta y = DeltaI/I + Deltalambda/lambda + DeltaA/A + DeltaS/S
# DeltaS/S = 0.177468 (17.747 %)
#
# Ca II line-by-line y-error bars
# --------------------------------------------------------------------------------------------------------------
#  lambda(nm) |       dI/I |       dl/l |       dA/A |       dS/S |         dy |          Y |           Y +/- dy
# --------------------------------------------------------------------------------------------------------------
#      315.89 |   0.000305 |  0.0001583 |       0.25 |   0.177468 |   0.427930 |   24.37198 |   24.37198 +/- 0.42793
#      317.93 |   0.000305 |  0.0001573 |       0.25 |   0.177468 |   0.427929 |   23.77198 |   23.77198 +/- 0.42793
#      370.60 |   0.000805 |  0.0001349 |       0.25 |   0.177468 |   0.428407 |   26.42198 |   26.42198 +/- 0.42841
#      373.69 |   0.000805 |  0.0001338 |       0.25 |   0.177468 |   0.428406 |   25.80198 |   25.80198 +/- 0.42841
#      393.36 |   0.000805 |  0.0001271 |       0.25 |   0.177468 |   0.428399 |   25.30198 |   25.30198 +/- 0.42840
#      396.85 |   0.000805 |  0.0001260 |       0.25 |   0.177468 |   0.428398 |   26.05198 |   26.05198 +/- 0.42840
#
# Ca I line-by-line y-error bars
# -----------------------------------------------------------------------------------------------
#  lambda(nm) | grade |       dI/I |       dl/l |       dA/A |         dy |          Y
# -----------------------------------------------------------------------------------------------
#      458.14 |     C |   0.004887 |  0.0001091 |       0.25 |   0.254996 |   32.88000
#      458.58 |     C |   0.005962 |  0.0001090 |       0.25 |   0.256071 |   32.65000
#      526.17 |     D |   0.001515 |  0.0000950 |       0.50 |   0.501610 |   35.07000
#      558.19 |     D |   0.003290 |  0.0000896 |       0.50 |   0.503379 |   34.80000
#      560.28 |     D |   0.003197 |  0.0000892 |       0.50 |   0.503287 |   34.85000
#      610.27 |     C |   0.001359 |  0.0000819 |       0.25 |   0.251441 |   35.97000
#      612.22 |     C |   0.000025 |  0.0000817 |       0.25 |   0.250107 |   35.23000
#      616.21 |     C |   0.001152 |  0.0000811 |       0.25 |   0.251233 |   34.88000
#      616.95 |     D |   0.000663 |  0.0000810 |       0.50 |   0.500744 |   34.82000
#      445.58 |     C |   0.000101 |  0.0001122 |       0.25 |   0.250213 |   34.48000
#
# Ca II Saha-corrected Y values
# ----------------------------------------------------------------------
#  1. E = 106139 cm^-1   Raw Y = 32.09000   Corrected Y = 24.37198
#  2. E = 106158 cm^-1   Raw Y = 31.49000   Corrected Y = 23.77198
#  3. E = 101466 cm^-1   Raw Y = 34.14000   Corrected Y = 26.42198
#  4. E = 101466 cm^-1   Raw Y = 33.52000   Corrected Y = 25.80198
#  5. E = 74714 cm^-1   Raw Y = 33.02000   Corrected Y = 25.30198
#  6. E = 74491 cm^-1   Raw Y = 33.77000   Corrected Y = 26.05198
# Temperature change = 0.002938 K
#
# ****************************************************************************************************
# CONVERGENCE ACHIEVED
# ****************************************************************************************************
# Final temperature = 9516.771 +/- 755.520 K
# Final electron density = 1.994029e+18 +/- 1.164218e+17 cm^-3
#
#
# ===============================================================================================================================================================================
# FINAL SAHA-BOLTZMANN ITERATION TABLE
# ===============================================================================================================================================================================
# Iter |        T_in |      σT_in |        omega |              Ne |             σNe |      Saha |     σSaha |          Slope |        σSlope |       T_out |     σT_out
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#    0 |    7292.823 |   2001.854 | 5.97337996e-04 |    2.092618e+18 |    2.057894e+17 |   7.27051 |   0.51009 |  -1.441117e-04 |  1.154289e-05 |    9983.761 |    799.667
#    1 |    9983.761 |    799.667 | 6.32840871e-04 |    1.975220e+18 |    1.180496e+17 |   7.79935 |   0.17991 |  -1.524686e-04 |  1.208718e-05 |    9436.547 |    748.097
#    2 |    9436.547 |    748.097 | 6.25837910e-04 |    1.997322e+18 |    1.161510e+17 |   7.70367 |   0.17707 |  -1.509566e-04 |  1.198723e-05 |    9531.064 |    756.847
#    3 |    9531.064 |    756.847 | 6.27055398e-04 |    1.993444e+18 |    1.164704e+17 |   7.72056 |   0.17754 |  -1.512235e-04 |  1.200483e-05 |    9514.240 |    755.285
#    4 |    9514.240 |    755.285 | 6.26838920e-04 |    1.994133e+18 |    1.164133e+17 |   7.71757 |   0.17745 |  -1.511762e-04 |  1.200171e-05 |    9517.219 |    755.562
#    5 |    9517.219 |    755.562 | 6.26877258e-04 |    1.994011e+18 |    1.164234e+17 |   7.71810 |   0.17747 |  -1.511846e-04 |  1.200227e-05 |    9516.691 |    755.513
#    6 |    9516.691 |    755.513 | 6.26870464e-04 |    1.994032e+18 |    1.164216e+17 |   7.71800 |   0.17747 |  -1.511831e-04 |  1.200217e-05 |    9516.784 |    755.521
#    7 |    9516.784 |    755.521 | 6.26871668e-04 |    1.994029e+18 |    1.164219e+17 |   7.71802 |   0.17747 |  -1.511834e-04 |  1.200218e-05 |    9516.768 |    755.520
#    8 |    9516.768 |    755.520 | 6.26871454e-04 |    1.994029e+18 |    1.164218e+17 |   7.71802 |   0.17747 |  -1.511833e-04 |  1.200218e-05 |    9516.771 |    755.520
# ===============================================================================================================================================================================
#
# ====================================================================================================
# FINAL RESULTS
# ====================================================================================================
# Initial Ca I temperature = 7292.823 +/- 2001.854 K
# Final slope = -1.511833086e-04 +/- 1.200218146e-05 cm
# Final temperature = 9516.771 +/- 755.520 K
# Final omega = 6.268714543e-04 +/- 1.503564686e-05 nm
# Final electron density = 1.994029e+18 +/- 1.164218e+17 cm^-3
# Final Saha correction = 7.718018 +/- 0.177468
# ====================================================================================================
#
# ====================================================================================================
# UNCERTAINTY SUMMARY
# ====================================================================================================
# Stark width = 0.250 +/- 0.009 nm
# Relative Stark-width uncertainty = 3.440 %
# Final relative slope uncertainty = 7.939 %
# Final relative temperature uncertainty = 7.939 %
# Final relative electron-density uncertainty = 5.839 %
# Final Saha relative uncertainty (DeltaS/S) = 0.17747 (common Saha contribution; line-specific Ca II Delta y also includes dI/I, dl/l and dA/A)
# ====================================================================================================
